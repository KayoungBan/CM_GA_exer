# %%
import random
import numpy as np
import math
from mpl_toolkits.mplot3d import Axes3D
from pandas import DataFrame
from matplotlib import pyplot as plt
# x(t)=Acos(wt+pi)
#mass=1(kg), k=5 >> w=(k/m)**0.5
#Amplitude=2
#pi=0

#t=np.arange(0,10.01,0.01)


t = np.arange(0,5,0.01)
theta = np.arange(0,5,0.01)
A=3
pi=3
m=2
k=5
w=(k//m)**0.5
err=np.random.uniform(-1,1, size=(len(t),))/100


f = t*np.cos(theta)

table = {'t' : t,'theta': theta, 'x' : f}


data = DataFrame(table)
data.to_csv("//home//ban94gy//jupyter//ML//exer//os_so.csv")

plt.plot(t,f)
plt.xlabel('time')  # x-axis
plt.ylabel('x(t)')  # y-axis
plt.grid()  # grid
plt.show()  # plot show

# fig = plt.figure(figsize=(20,20))  
# ax = fig.add_subplot(221, projection='3d')  
# ax.plot(t, f)
