# %%
import operator
import math
import random
import pandas as pd
import numpy
import time

from deap import algorithms
from deap import base
from deap import creator
from deap import tools
from deap import gp
import matplotlib.pyplot as plt


hof[0]=add(1,3)

def calcul1(oper(var1,var2)):
    if oper=add:
        return var1+var2
    if oper=sub:
        return var1-var2
    if oper=mul:
        return var1*var2
    

calcul1(hof[0])
# Out:
#   File "<ipython-input-5-1122355d0856>", line 18
#     def calcul1(oper(var1,var2)):
#                     ^
# SyntaxError: invalid syntax

# %%
from functools import partial

import operator
import math
import random
import pandas as pd
import numpy
import time

from deap import algorithms
from deap import base
from deap import creator
from deap import tools
from deap import gp
import matplotlib.pyplot as plt
import numpy as np
import deap.gp
import deap.tools

from glyph import gp
from glyph.assessment import const_opt_scalar
from glyph.utils import Memoize
from glyph.utils.numeric import silent_numpy, nrmse


class Individual(gp.AExpressionTree):
    """The gp representation (genotype) of the actuator for the control problem."""

    pset = gp.numpy_primitive_set(arity=1, categories=['algebraic', 'trigonometric', 'exponential', 'symc'])


@silent_numpy
def error(ind, *args):
    g = lambda x: x**2 +y*3 - 1.1
    points = np.linspace(-1, 1, 100, endpoint=True)
    y = g(points)
    f = gp.individual.numpy_phenotype(ind)
    yhat = f(points, *args)

    if np.isscalar(yhat):
        yhat = np.ones_like(y) * yhat
    return nrmse(y, yhat)


@Memoize
def measure(ind):
    popt, err_opr = const_opt_scalar(error, ind)
    ind.popt = popt
    return err_opr, len(ind)


def update_fitness(population, map=map):
    invalid = [p for p in population if not p.fitness.valid]
    fitnesses = map(measure, invalid)
    for ind, fit in zip(invalid, fitnesses):
        ind.fitness.values = fit
    return population


def main():
    pop_size = 100

    mate = deap.gp.cxOnePoint
    expr_mut = partial(deap.gp.genFull, min_=0, max_=2)
    mutate = partial(deap.gp.mutUniform, expr=expr_mut, pset=Individual.pset)

    algorithm = gp.algorithms.AgeFitness(mate, mutate, deap.tools.selNSGA2, Individual.create_population)

    pop = update_fitness(Individual.create_population(pop_size))

    for gen in range(20):
        pop = algorithm.evolve(pop)
        pop = update_fitness(pop)
        best = deap.tools.selBest(pop, 1)[0]
        print(gp.individual.simplify_this(best), best.fitness.values)


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cb33169ee8ab> in <module>()
#      77
#      78 if __name__ == "__main__":
# ---> 79     main()
#
# <ipython-input-2-cb33169ee8ab> in main()
#      67     algorithm = gp.algorithms.AgeFitness(mate, mutate, deap.tools.selNSGA2, Individual.create_population)
#      68
# ---> 69     pop = update_fitness(Individual.create_population(pop_size))
#      70
#      71     for gen in range(20):
#
# <ipython-input-2-cb33169ee8ab> in update_fitness(population, map)
#      53     invalid = [p for p in population if not p.fitness.valid]
#      54     fitnesses = map(measure, invalid)
# ---> 55     for ind, fit in zip(invalid, fitnesses):
#      56         ind.fitness.values = fit
#      57     return population
#
# ~/ban/local/lib/python3.5/site-packages/glyph/utils/__init__.py in __call__(self, *args, **kwargs)
#      23         key = str(args) + str(kwargs)
#      24         if key not in self.memo:
# ---> 25             self.memo[key] = self.fn(*args, **kwargs)
#      26         return self.memo[key]
#      27
#
# <ipython-input-2-cb33169ee8ab> in measure(ind)
#      45 @Memoize
#      46 def measure(ind):
# ---> 47     popt, err_opr = const_opt_scalar(error, ind)
#      48     ind.popt = popt
#      49     return err_opr, len(ind)
#
# ~/ban/local/lib/python3.5/site-packages/glyph/assessment.py in const_opt(measure, individual, lsq, default_constants, f_kwargs, **kwargs)
#     150     terminals = [t.name for t in individual.terminals]
#     151     if any(constant in terminals for constant in individual.pset.constants):
# --> 152         res = opt(fun=closure, x0=p0, **kwargs)
#     153         popt = res.x if res.x.shape else np.array([res.x])
#     154         measure_opt = res.fun
#
# ~/ban/local/lib/python3.5/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     479         return _minimize_cg(fun, x0, args, jac, callback, **options)
#     480     elif meth == 'bfgs':
# --> 481         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     482     elif meth == 'newton-cg':
#     483         return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~/ban/local/lib/python3.5/site-packages/scipy/optimize/optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, **unknown_options)
#     941     else:
#     942         grad_calls, myfprime = wrap_function(fprime, args)
# --> 943     gfk = myfprime(x0)
#     944     k = 0
#     945     N = len(x0)
#
# ~/ban/local/lib/python3.5/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# ~/ban/local/lib/python3.5/site-packages/scipy/optimize/optimize.py in approx_fprime(xk, f, epsilon, *args)
#     701
#     702     """
# --> 703     return _approx_fprime_helper(xk, f, epsilon, args=args)
#     704
#     705
#
# ~/ban/local/lib/python3.5/site-packages/scipy/optimize/optimize.py in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     635     """
#     636     if f0 is None:
# --> 637         f0 = f(*((xk,) + args))
#     638     grad = numpy.zeros((len(xk),), float)
#     639     ei = numpy.zeros((len(xk),), float)
#
# ~/ban/local/lib/python3.5/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# ~/ban/local/lib/python3.5/site-packages/glyph/assessment.py in closure(consts)
#     143     @functools.wraps(measure)
#     144     def closure(consts):
# --> 145         return measure(individual, *consts, **f_kwargs)
#     146
#     147     p0 = default_constants(individual)
#
# ~/ban/local/lib/python3.5/site-packages/glyph/utils/numeric.py in closure(*args, **kwargs)
#      44     def closure(*args, **kwargs):
#      45         with np.errstate(all='ignore'):
# ---> 46             return func(*args, **kwargs)
#      47     return closure
#      48
#
# <ipython-input-2-cb33169ee8ab> in error(ind, *args)
#      34     g = lambda x: x**2 +y*3 - 1.1
#      35     points = np.linspace(-1, 1, 100, endpoint=True)
# ---> 36     y = g(points)
#      37     f = gp.individual.numpy_phenotype(ind)
#      38     yhat = f(points, *args)
#
# <ipython-input-2-cb33169ee8ab> in <lambda>(x)
#      32 @silent_numpy
#      33 def error(ind, *args):
# ---> 34     g = lambda x: x**2 +y*3 - 1.1
#      35     points = np.linspace(-1, 1, 100, endpoint=True)
#      36     y = g(points)
#
# NameError: free variable 'y' referenced before assignment in enclosing scope
