# %%
def plot_pred(hof):
    func = toolbox.compile(expr=hof[0])
    y_hat = []
    y = []
    y_r = []
    for a, i in enumerate(t):
        y_hat.append(func(i))
        y.append(p[a])
        y_r.append(p_r[a])
        
    from matplotlib import pyplot as plt
    plt.plot(t,y)
    
    plt.plot(t, y_hat)
    plt.plot(t, y_r)
    plt.xlabel('time')  # x-axis
    plt.ylabel('x(t)')  # y-axis
    plt.title('Data')  # title
    plt.grid()  # grid
    plt.legend(['with error','predicted','real'])
    plt.show()  # plot show
###############################import###############################
import operator
import math
import random
import pandas as pd
import numpy
import time
import os
import dill

from deap import algorithms
from deap import base
from deap import creator
from deap import tools
from deap import gp
from scoop import futures

from concurrent.futures import ProcessPoolExecutor
import matplotlib.pyplot as plt
import multiprocessing as mp

###################################################################

###################### Define functions############################
def safeDiv(left, right):
    try:
        return left / right
    except ZeroDivisionError:
        return 1
    
def sqrt(left):
    if left>=0:
        return left**0.5
    else:
        return 0
    
def expe(left):
    if left>=0:
        return numpy.exp(-left)
    else:
        return 0

    
    
random.seed(time.time())
ran1 = int(random.random()*10)
ran2 =int(random.random()*10)



pset = gp.PrimitiveSet("MAIN", 1)
pset.addPrimitive(operator.add, 2)
#pset.addPrimitive(operator.sub, 2)
pset.addPrimitive(operator.mul, 2)
pset.addPrimitive(expe, 1)
#set.addPrimitive(safeDiv, 2)
pset.addPrimitive(sqrt,1)
pset.addPrimitive(operator.neg, 1)
pset.addPrimitive(math.cos, 1)
pset.addPrimitive(math.sin, 1)
try:
    pset.addEphemeralConstant("rand", random.randint(1,5))
except:
    print("")
#pset.addEphemeralConstant("rand", lambda: random.randint(1,5))
#pset.addEphemeralConstant("rand"+str(ran1)+str(ran2), lambda: random.randint(min(ran1,ran2),max(ran1,ran2)))
pset.renameArguments(ARG0='x')



###################################################################
pool = mp.Pool()

creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", gp.PrimitiveTree, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("expr", gp.genHalfAndHalf, pset=pset, min_=1, max_=3)
toolbox.register("individual", tools.initIterate, creator.Individual, toolbox.expr)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("compile", gp.compile, pset=pset)
#toolbox.register("map", futures.map)

#########################input DATA#################################

def evalSymbReg(individual, points):
    # Transform the tree expression in a callable function
    func = toolbox.compile(expr=individual)

    # Evaluate the mean squared error between the expression
    sqerrors = ((func(x) - f[x])**2 for x in points)

    try:
        return max(sqerrors),
    except IndexError:
        return max(sqerrors),
    
toolbox.register("map", pool.map)


g = pd.read_csv('os.csv')
p = g['x']
g_r = pd.read_csv('os_r.csv')
p_r = g_r['x']

t = list(numpy.arange(6,15,0.01))
f = {}
for i in range(len(t)):
    f[t[i]] = p[i]
    
ff = {}
for i in range(len(t)):
    ff[t[i]] = p_r[i]
    
    
toolbox.register("evaluate", evalSymbReg, points=t)
toolbox.register("select", tools.selTournament, tournsize=10)
toolbox.register("mate", gp.cxOnePoint)
toolbox.register("expr_mut", gp.genFull, min_=1, max_=3)
toolbox.register("mutate", gp.mutUniform, expr=toolbox.expr_mut, pset=pset)

toolbox.decorate("mate", gp.staticLimit(key=operator.attrgetter("height"), max_value=6))
toolbox.decorate("mutate", gp.staticLimit(key=operator.attrgetter("height"), max_value=6))


def main():
    pop = toolbox.population(n=10000)
    hof = tools.HallOfFame(1)
    
    stats_fit = tools.Statistics(lambda ind: ind.fitness.values)
    stats_size = tools.Statistics(len)
    mstats = tools.MultiStatistics(fitness=stats_fit, size=stats_size)
    
    mstats.register("min", numpy.min)
    mstats.register("max", numpy.max)
    
    
    #############################################C.O, Muta,Gener##########
    try:
        pop, log = algorithms.eaSimple(pop, toolbox, 0.8, 0.8, 1000, stats=mstats,
                                       halloffame=hof, verbose=True)
        print (hof[0])
        
        plot_pred(hof)

    except MemoryError:
        print (hof[0])
        plot_pred(hof)

    except KeyboardInterrupt:
        print (hof[0])
        plot_pred(hof)
    


if __name__ == "__main__":
    main()
# Out:
# /home/ban94gy/ban/local/lib/python3.5/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /home/ban94gy/ban/local/lib/python3.5/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
#    	      	        fitness         	    size
#    	      	------------------------	-----------
# gen	nevals	max       	min     	max	min
# 0  	10000 	1.0197e+10	0.703345	14 	2
# 1  	9629  	1.28712e+14	0.599679	20 	2
# 2  	9593  	4.07881e+10	0.599679	24 	2
# 3  	9580  	2.75863e+10	0.599679	24 	2
# 4  	9618  	1.06494e+10	0.502584	30 	2
# 5  	9592  	5.19872e+12	0.414326	30 	2
# 6  	9597  	7.37218e+11	0.414326	34 	2
# 7  	9591  	5.93172e+12	0.414326	34 	2
# 8  	9649  	2.96643e+12	0.414326	33 	2
# 9  	9571  	1.46364e+10	0.242583	33 	2
# 10 	9589  	5.15536e+12	0.150077	38 	2
# 11 	9586  	2.95981e+12	0.0735436	37 	2
# 12 	9592  	2.57058e+14	0.0663937	37 	2
# 13 	9593  	4.64668e+11	0.0663937	40 	2
# 14 	9598  	9.44778e+10	0.0663937	38 	2
# 15 	9615  	4.0788e+10 	0.0663937	39 	2
# 16 	9594  	6.67851e+12	0.0503818	39 	2
# 17 	9588  	5.72818e+11	0.0503818	43 	2
# 18 	9600  	4.07881e+10	0.0470747	40 	2
# 19 	9590  	9.17731e+10	0.0463015	43 	2
# 20 	9582  	7.47269e+13	0.0462644	43 	2
# 21 	9582  	8.33093e+13	0.0461396	45 	2
# 22 	9597  	1.92989e+13	0.0457916	46 	2
# 23 	9633  	5.1087e+12 	0.0456055	44 	2
# 24 	9573  	2.44242e+12	0.044223 	46 	2
# 25 	9642  	8.52531e+12	0.044223 	45 	2
# 26 	9587  	1.31807e+14	0.044223 	45 	2
# 27 	9615  	8.52598e+12	0.0433541	48 	2
# 28 	9614  	9.62244e+10	0.0425748	50 	2
# 29 	9602  	3.41006e+13	0.0413641	51 	2
# 30 	9566  	4.95529e+12	0.0413641	51 	2
# 31 	9576  	1.34812e+11	0.0413641	52 	2
# 32 	9593  	2.20524e+12	0.0413641	52 	2
# 33 	9588  	2.32954e+12	0.0413641	51 	2
# 34 	9563  	8.3736e+12 	0.0413641	51 	2
# 35 	9588  	3.66866e+13	0.0413641	50 	2
# 36 	9572  	6.53076e+11	0.0413641	52 	2
# 37 	9545  	1.57166e+11	0.0413641	51 	2
# 38 	9576  	8.77707e+12	0.0413641	52 	2
# 39 	9612  	1.37483e+14	0.0413641	51 	2
# 40 	9591  	8.77707e+12	0.0413641	55 	2
# 41 	9564  	1.37483e+14	0.0413641	52 	2
# 42 	9570  	1.40433e+14	0.0413641	55 	2
# 43 	9588  	1.57166e+11	0.0413641	51 	2
# 44 	9606  	1.37754e+12	0.0413641	54 	2
# 45 	9577  	8.23798e+12	0.0413641	57 	2
# 46 	9573  	4.08172e+10	0.0413641	57 	2
# 47 	9585  	6.11852e+11	0.0413641	57 	2
# 48 	9622  	4.05441e+10	0.0413641	57 	2
# 49 	9612  	1.68944e+11	0.0413641	51 	2
# 50 	9608  	3.69013e+10	0.0413641	55 	2
# 51 	9571  	1.47626e+11	0.0413641	57 	2
# 52 	9627  	1.63269e+11	0.0413641	57 	2
# 53 	9591  	9.17137e+12	0.0413641	57 	2
# 54 	9616  	1.63269e+11	0.0413641	57 	2
# 55 	9579  	8.77182e+12	0.0413641	57 	2
# 56 	9622  	1.63269e+11	0.0413641	57 	2
# 57 	9583  	6.28665e+11	0.0413641	60 	2
# 58 	9600  	1.01367e+11	0.0413641	62 	2
# 59 	9590  	1.62657e+11	0.0413641	64 	2
# 60 	9613  	1.32368e+11	0.0413641	63 	2
# 61 	9575  	3.92916e+10	0.0413641	63 	2
# 62 	9608  	2.2053e+12 	0.0413641	63 	2
# 63 	9580  	1.17419e+12	0.0413641	63 	2
# 64 	9645  	2.29127e+12	0.0413641	63 	2
# 65 	9627  	5.51346e+11	0.0413641	62 	2
# 66 	9582  	3.92916e+10	0.0413641	63 	2
# 67 	9640  	1.57166e+11	0.0413641	63 	2
# 68 	9603  	6.0586e+11 	0.0413641	63 	2
# mul(mul(add(mul(add(sqrt(x), expe(x)), add(x, expe(x))), mul(mul(cos(x), sqrt(x)), sin(sqrt(x)))), cos(add(neg(add(x, x)), neg(add(x, x))))), sqrt(expe(neg(add(neg(x), expe(x))))))
# Process ForkPoolWorker-391:
# Process ForkPoolWorker-396:
# Process ForkPoolWorker-397:
# Process ForkPoolWorker-377:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-393:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Process ForkPoolWorker-389:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-381:
# Process ForkPoolWorker-371:
# Process ForkPoolWorker-365:
# Process ForkPoolWorker-364:
# Process ForkPoolWorker-387:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
# Process ForkPoolWorker-386:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-368:
# Traceback (most recent call last):
# Process ForkPoolWorker-369:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-378:
# Process ForkPoolWorker-394:
# Process ForkPoolWorker-392:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-374:
# Process ForkPoolWorker-367:
# Process ForkPoolWorker-375:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-399:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-370:
# Process ForkPoolWorker-395:
# Process ForkPoolWorker-373:
# Process ForkPoolWorker-366:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<string>", line 1, in <lambda>
# Process ForkPoolWorker-382:
# Process ForkPoolWorker-388:
# Process ForkPoolWorker-398:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Process ForkPoolWorker-400:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-380:
# Process ForkPoolWorker-379:
# Process ForkPoolWorker-362:
# Process ForkPoolWorker-372:
# Process ForkPoolWorker-383:
# Process ForkPoolWorker-376:
# Process ForkPoolWorker-361:
# Process ForkPoolWorker-384:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-390:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-363:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
# Process ForkPoolWorker-385:
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<string>", line 1, in <lambda>
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<string>", line 1, in <lambda>
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<string>", line 1, in <lambda>
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<string>", line 1, in <lambda>
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-5-380c95d0616c>", line 60, in expe
#     return numpy.exp(-left)
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-5-380c95d0616c>", line 60, in expe
#     return numpy.exp(-left)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-5-380c95d0616c>", line 60, in expe
#     return numpy.exp(-left)
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-5-380c95d0616c>", line 60, in expe
#     return numpy.exp(-left)
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
# KeyboardInterrupt
#   File "<string>", line 1, in <lambda>
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
# KeyboardInterrupt
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<ipython-input-5-380c95d0616c>", line 58, in expe
#     def expe(left):
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-5-380c95d0616c>", line 109, in evalSymbReg
#     func = toolbox.compile(expr=individual)
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
# KeyboardInterrupt
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<ipython-input-5-380c95d0616c>", line 60, in expe
#     return numpy.exp(-left)
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<string>", line 1, in <lambda>
#   File "<string>", line 1, in <lambda>
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/home/ban94gy/ban/local/lib/python3.5/site-packages/deap/gp.py", line 475, in compile
#     return eval(code, pset.context, {})
#   File "<ipython-input-5-380c95d0616c>", line 58, in expe
#     def expe(left):
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
# KeyboardInterrupt
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<string>", line 1, in <lambda>
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<string>", line 1, in <lambda>
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<string>", line 1, in <lambda>
#   File "<string>", line 1, in <lambda>
#   File "<string>", line 1, in <lambda>
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<string>", line 1, in <lambda>
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-5-380c95d0616c>", line 60, in expe
#     return numpy.exp(-left)
#   File "<ipython-input-5-380c95d0616c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-5-380c95d0616c>", line 60, in expe
#     return numpy.exp(-left)
# KeyboardInterrupt
#   File "<ipython-input-5-380c95d0616c>", line 59, in expe
#     if left>=0:
#   File "<string>", line 1, in <module>
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
# KeyboardInterrupt
#   File "<string>", line 1, in <lambda>
#   File "<string>", line 1, in <lambda>
#   File "<string>", line 1, in <lambda>
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-5-380c95d0616c>", line 60, in expe
#     return numpy.exp(-left)
#   File "<ipython-input-5-380c95d0616c>", line 60, in expe
#     return numpy.exp(-left)
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-5-380c95d0616c>", line 60, in expe
#     return numpy.exp(-left)
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-5-380c95d0616c>", line 59, in expe
#     if left>=0:
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-5-380c95d0616c>", line 60, in expe
#     return numpy.exp(-left)
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-5-380c95d0616c>", line 54, in sqrt
#     return left**0.5
#   File "<ipython-input-5-380c95d0616c>", line 60, in expe
#     return numpy.exp(-left)
#   File "<ipython-input-5-380c95d0616c>", line 53, in sqrt
#     if left>=0:
#   File "<ipython-input-5-380c95d0616c>", line 53, in sqrt
#     if left>=0:
#   File "<ipython-input-5-380c95d0616c>", line 54, in sqrt
#     return left**0.5
#   File "<ipython-input-5-380c95d0616c>", line 59, in expe
#     if left>=0:
#   File "<string>", line 1, in <lambda>
# KeyboardInterrupt
#   File "<ipython-input-5-380c95d0616c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<string>", line 1, in <lambda>
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<ipython-input-5-380c95d0616c>", line 60, in expe
#     return numpy.exp(-left)
#   File "<ipython-input-5-380c95d0616c>", line 60, in expe
#     return numpy.exp(-left)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<ipython-input-5-380c95d0616c>", line 60, in expe
#     return numpy.exp(-left)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<ipython-input-5-380c95d0616c>", line 60, in expe
#     return numpy.exp(-left)
#   File "<ipython-input-5-380c95d0616c>", line 60, in expe
#     return numpy.exp(-left)
#   File "<string>", line 1, in <lambda>
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<ipython-input-5-380c95d0616c>", line 53, in sqrt
#     if left>=0:
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt

# %%
def plot_pred(hof):
    func = toolbox.compile(expr=hof[0])
    y_hat = []
    y = []
    y_r = []
    for a, i in enumerate(t):
        y_hat.append(func(i))
        y.append(p[a])
        y_r.append(p_r[a])
        
    from matplotlib import pyplot as plt
    plt.plot(t,y)
    
    plt.plot(t, y_hat)
    plt.plot(t, y_r)
    plt.xlabel('time')  # x-axis
    plt.ylabel('x(t)')  # y-axis
    plt.title('Data')  # title
    plt.grid()  # grid
    plt.legend(['with error','predicted','real'])
    plt.show()  # plot show
###############################import###############################
import operator
import math
import random
import pandas as pd
import numpy
import time
import os
import dill

from deap import algorithms
from deap import base
from deap import creator
from deap import tools
from deap import gp
from scoop import futures

from concurrent.futures import ProcessPoolExecutor
import matplotlib.pyplot as plt
import multiprocessing as mp

###################################################################

###################### Define functions############################
def safeDiv(left, right):
    try:
        return left / right
    except ZeroDivisionError:
        return 1
    
def sqrt(left):
    if left>=0:
        return left**0.5
    else:
        return 0
    
def expe(left):
    if left>=0:
        return numpy.exp(-left)
    else:
        return 0

    
    
random.seed(time.time())
ran1 = int(random.random()*10)
ran2 =int(random.random()*10)



pset = gp.PrimitiveSet("MAIN", 1)
pset.addPrimitive(operator.add, 2)
#pset.addPrimitive(operator.sub, 2)
pset.addPrimitive(operator.mul, 2)
pset.addPrimitive(expe, 1)
#set.addPrimitive(safeDiv, 2)
pset.addPrimitive(sqrt,1)
pset.addPrimitive(operator.neg, 1)
pset.addPrimitive(math.cos, 1)
pset.addPrimitive(math.sin, 1)
try:
    pset.addEphemeralConstant("rand", random.randint(1,5))
except:
    print("")
#pset.addEphemeralConstant("rand", lambda: random.randint(1,5))
#pset.addEphemeralConstant("rand"+str(ran1)+str(ran2), lambda: random.randint(min(ran1,ran2),max(ran1,ran2)))
pset.renameArguments(ARG0='x')



###################################################################
pool = mp.Pool()

creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", gp.PrimitiveTree, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("expr", gp.genHalfAndHalf, pset=pset, min_=1, max_=3)
toolbox.register("individual", tools.initIterate, creator.Individual, toolbox.expr)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("compile", gp.compile, pset=pset)
#toolbox.register("map", futures.map)

#########################input DATA#################################

def evalSymbReg(individual, points):
    # Transform the tree expression in a callable function
    func = toolbox.compile(expr=individual)

    # Evaluate the mean squared error between the expression
    sqerrors = ((func(x) - f[x])**2 for x in points)

    try:
        return max(sqerrors),
    except IndexError:
        return max(sqerrors),
    
toolbox.register("map", pool.map)


g = pd.read_csv('os_so.csv')
p = g['x']
g_r = pd.read_csv('os_so.csv')
p_r = g_r['x']

t = list(numpy.arange(0,5,0.01))
f = {}
for i in range(len(t)):
    f[t[i]] = p[i]
    
ff = {}
for i in range(len(t)):
    ff[t[i]] = p_r[i]
    
    
toolbox.register("evaluate", evalSymbReg, points=t)
toolbox.register("select", tools.selTournament, tournsize=10)
toolbox.register("mate", gp.cxOnePoint)
toolbox.register("expr_mut", gp.genFull, min_=1, max_=3)
toolbox.register("mutate", gp.mutUniform, expr=toolbox.expr_mut, pset=pset)

toolbox.decorate("mate", gp.staticLimit(key=operator.attrgetter("height"), max_value=6))
toolbox.decorate("mutate", gp.staticLimit(key=operator.attrgetter("height"), max_value=6))


def main():
    pop = toolbox.population(n=10000)
    hof = tools.HallOfFame(1)
    
    stats_fit = tools.Statistics(lambda ind: ind.fitness.values)
    stats_size = tools.Statistics(len)
    mstats = tools.MultiStatistics(fitness=stats_fit, size=stats_size)
    
    mstats.register("min", numpy.min)
    mstats.register("max", numpy.max)
    
    
    #############################################C.O, Muta,Gener##########
    try:
        pop, log = algorithms.eaSimple(pop, toolbox, 0.8, 0.8, 1000, stats=mstats,
                                       halloffame=hof, verbose=True)
        print (hof[0])
        
        plot_pred(hof)

    except MemoryError:
        print (hof[0])
        plot_pred(hof)

    except KeyboardInterrupt:
        print (hof[0])
        plot_pred(hof)
    


if __name__ == "__main__":
    main()
# Out:
# /home/ban94gy/ban/local/lib/python3.5/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /home/ban94gy/ban/local/lib/python3.5/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
#    	      	         fitness          	    size
#    	      	--------------------------	-----------
# gen	nevals	max        	min       	max	min
# 0  	10000 	3.82887e+07	0.00146822	15 	2
# 1  	9630  	1.53758e+06	0.00138992	22 	2
# 2  	9579  	9.57229e+06	0.00117545	24 	2
# 3  	9621  	384372     	0.00117545	31 	2
# 4  	9586  	384465     	0.00117545	28 	2
# 5  	9565  	1.53758e+06	0.000561683	28 	2
# 6  	9601  	384380     	0.000561683	27 	2
# 7  	9569  	490463     	0.000561683	24 	2
# 8  	9614  	62213.8    	0.000561371	25 	2
# 9  	9622  	553876     	0.00053325 	25 	2
# 10 	9602  	7.6732e+06 	0.00053325 	27 	2
# 11 	9596  	988135     	9.8772e-05 	27 	2
# 12 	9598  	384465     	5.50904e-05	25 	2
# 13 	9565  	4.54657e+07	5.50904e-05	24 	2
# 14 	9627  	14259.9    	5.50904e-05	23 	2
# 15 	9610  	355252     	5.50904e-05	24 	2
# 16 	9623  	1.42227e+06	5.50904e-05	24 	2
# 17 	9583  	384372     	5.12652e-05	25 	2
# 18 	9644  	384372     	5.12652e-05	23 	2
# 19 	9601  	1.53758e+06	5.12652e-05	24 	2
# 20 	9592  	325265     	5.12652e-05	24 	2
# 21 	9592  	9.57183e+06	5.12652e-05	23 	2
# 22 	9608  	61772.5    	5.12652e-05	22 	2
# 23 	9588  	384465     	5.12652e-05	27 	2
# 24 	9587  	384372     	5.12652e-05	24 	2
# 25 	9592  	392975     	5.12652e-05	23 	2
# 26 	9554  	384372     	5.12652e-05	23 	2
# 27 	9573  	1.91814e+06	5.12652e-05	24 	2
# 28 	9592  	61734.9    	5.12652e-05	24 	2
# 29 	9541  	384372     	5.12652e-05	24 	2
# 30 	9615  	363461     	5.12652e-05	24 	2
# 31 	9620  	6.15088e+06	5.12652e-05	25 	2
# 32 	9599  	384372     	5.12652e-05	27 	2
# 33 	9592  	121202     	5.12652e-05	24 	2
# 34 	9596  	385566     	5.12652e-05	23 	2
# 35 	9611  	384372     	5.12652e-05	25 	2
# 36 	9603  	719005     	5.12652e-05	24 	2
# 37 	9604  	388299     	5.12652e-05	25 	2
# 38 	9586  	384465     	5.12652e-05	24 	2
# 39 	9615  	15447.8    	5.12652e-05	25 	2
# 40 	9608  	66297.7    	5.12652e-05	25 	2
# 41 	9583  	384372     	5.12652e-05	23 	2
# 42 	9583  	61995.4    	5.12652e-05	25 	2
# 43 	9599  	384372     	5.12652e-05	23 	2
# 44 	9596  	6.15088e+06	5.12652e-05	25 	2
# 45 	9627  	1.4211e+06 	5.12652e-05	24 	2
# 46 	9617  	384372     	5.12652e-05	25 	2
# 47 	9597  	384372     	5.12652e-05	24 	2
# 48 	9583  	396855     	5.12652e-05	25 	2
# 49 	9577  	356216     	5.12652e-05	26 	2
# 50 	9580  	4.77651e+07	5.12652e-05	24 	2
# 51 	9578  	384372     	5.12652e-05	24 	2
# 52 	9594  	384372     	5.12652e-05	24 	2
# 53 	9582  	41556.1    	5.12652e-05	26 	2
# 54 	9637  	15447.8    	5.12652e-05	23 	2
# 55 	9549  	384372     	5.12652e-05	24 	2
# 56 	9607  	1.25568e+06	5.12652e-05	25 	2
# 57 	9610  	61734.9    	5.12652e-05	24 	2
# 58 	9604  	895666     	5.12652e-05	25 	2
# 59 	9606  	7.6732e+06 	5.12652e-05	24 	2
# 60 	9579  	384465     	5.12652e-05	25 	2
# 61 	9602  	308193     	5.12652e-05	24 	2
# 62 	9604  	72025.3    	5.12652e-05	23 	2
# 63 	9555  	858656     	5.12652e-05	24 	2
# 64 	9635  	6.15088e+06	5.12652e-05	25 	2
# 65 	9591  	384465     	5.12652e-05	25 	2
# 66 	9582  	246977     	5.12652e-05	24 	2
# 67 	9536  	74878.5    	5.12652e-05	23 	2
# 68 	9610  	385021     	5.12652e-05	23 	2
# 69 	9614  	61734.9    	5.12652e-05	25 	2
# 70 	9569  	384372     	5.12652e-05	26 	2
# 71 	9595  	384465     	5.12652e-05	26 	2
# 72 	9612  	4.6769e+08 	5.12652e-05	23 	2
# 73 	9625  	1.9606e+06 	5.12652e-05	25 	2
# 74 	9626  	15447.8    	5.12652e-05	25 	2
# 75 	9635  	983201     	5.12652e-05	23 	2
# 76 	9594  	57097.4    	5.12652e-05	25 	2
# 77 	9598  	308193     	5.12652e-05	25 	2
# 78 	9611  	384720     	5.12652e-05	25 	2
# 79 	9595  	354117     	5.12652e-05	23 	2
# 80 	9637  	484651     	5.12652e-05	24 	2
# 81 	9603  	61995.4    	5.12652e-05	24 	2
# 82 	9545  	384372     	5.12652e-05	25 	2
# 83 	9605  	106842     	5.12652e-05	24 	2
# 84 	9632  	384372     	5.12652e-05	23 	2
# 85 	9635  	384465     	5.12652e-05	24 	2
# 86 	9642  	61772.5    	5.12652e-05	26 	2
# 87 	9587  	61772.5    	5.12652e-05	23 	2
# 88 	9585  	61734.9    	5.12652e-05	25 	2
# 89 	9591  	1.53758e+06	5.12652e-05	23 	2
# 90 	9579  	385604     	5.12652e-05	24 	2
# 91 	9593  	15447.8    	5.12652e-05	26 	2
# 92 	9584  	3.54129e+07	5.12652e-05	25 	2
# 93 	9560  	384372     	5.12652e-05	23 	2
# 94 	9609  	384372     	5.12652e-05	24 	2
# 95 	9583  	61772.5    	5.12652e-05	25 	2
# 96 	9589  	287763     	5.12652e-05	25 	2
# 97 	9594  	616243     	5.12652e-05	23 	2
# 98 	9592  	246977     	5.12652e-05	25 	2
# 99 	9593  	4.54657e+07	5.12652e-05	24 	2
# 100	9577  	384372     	5.12652e-05	23 	2
# 101	9610  	15447.8    	5.12652e-05	25 	2
# 102	9633  	67842.8    	5.12652e-05	24 	2
# 103	9611  	384372     	5.12652e-05	23 	2
# 104	9585  	61734.9    	5.12652e-05	25 	2
# 105	9588  	73410.4    	5.12652e-05	24 	2
# 106	9602  	2.83027e+08	5.12652e-05	24 	2
# 107	9591  	384372     	5.12652e-05	24 	2
# 108	9604  	384465     	5.12652e-05	24 	2
# 109	9582  	61734.9    	5.12652e-05	23 	2
# 110	9645  	61734.9    	5.12652e-05	24 	2
# 111	9605  	61734.9    	5.12652e-05	25 	2
# 112	9615  	1.53758e+06	5.12652e-05	23 	2
# 113	9631  	65211.2    	5.12652e-05	23 	2
# 114	9593  	3.81352e+09	5.12652e-05	27 	2
# 115	9626  	384372     	5.12652e-05	25 	2
# 116	9566  	392975     	5.12652e-05	24 	2
# 117	9607  	384465     	5.12652e-05	23 	2
# 118	9593  	2.30318e+06	5.12652e-05	23 	2
# 119	9565  	384372     	5.12652e-05	23 	2
# 120	9641  	1.53152e+08	5.12652e-05	24 	2
# 121	9588  	456435     	5.12652e-05	25 	2
# 122	9595  	384372     	5.12652e-05	27 	2
# 123	9583  	412512     	5.12652e-05	25 	2
# Process ForkPoolWorker-306:
# Process ForkPoolWorker-292:
# Process ForkPoolWorker-278:
# Process ForkPoolWorker-285:
# Process ForkPoolWorker-295:
# Process ForkPoolWorker-274:
# Traceback (most recent call last):
# Process ForkPoolWorker-286:
# Process ForkPoolWorker-305:
# Process ForkPoolWorker-271:
# Process ForkPoolWorker-283:
# Process ForkPoolWorker-280:
# Process ForkPoolWorker-281:
# Process ForkPoolWorker-282:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-284:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
# expe(sqrt(add(add(mul(x, sqrt(x)), expe(expe(x))), mul(cos(sin(x)), sin(expe(x))))))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-307:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-301:
# Process ForkPoolWorker-288:
# Process ForkPoolWorker-289:
# Traceback (most recent call last):
# Process ForkPoolWorker-275:
# Process ForkPoolWorker-300:
# Process ForkPoolWorker-303:
# Process ForkPoolWorker-272:
# Process ForkPoolWorker-277:
# Process ForkPoolWorker-287:
# Process ForkPoolWorker-296:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
# Process ForkPoolWorker-290:
# Process ForkPoolWorker-273:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-270:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# Process ForkPoolWorker-293:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-269:
# Traceback (most recent call last):
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-ee4f88abbe3c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Process ForkPoolWorker-298:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
#   File "<ipython-input-3-ee4f88abbe3c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Process ForkPoolWorker-299:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<string>", line 1, in <lambda>
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-3-ee4f88abbe3c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-3-ee4f88abbe3c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "<string>", line 1, in <lambda>
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-3-ee4f88abbe3c>", line 53, in sqrt
#     if left>=0:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "<ipython-input-3-ee4f88abbe3c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-3-ee4f88abbe3c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "<ipython-input-3-ee4f88abbe3c>", line 58, in expe
#     def expe(left):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "<ipython-input-3-ee4f88abbe3c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-ee4f88abbe3c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<string>", line 1, in <lambda>
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<string>", line 1, in <lambda>
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-3-ee4f88abbe3c>", line 60, in expe
#     return numpy.exp(-left)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-3-ee4f88abbe3c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-3-ee4f88abbe3c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-ee4f88abbe3c>", line 58, in expe
#     def expe(left):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-ee4f88abbe3c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
# Traceback (most recent call last):
#   File "<ipython-input-3-ee4f88abbe3c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<string>", line 1, in <lambda>
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-291:
# Process ForkPoolWorker-276:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "<string>", line 1, in <lambda>
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
# Process ForkPoolWorker-294:
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-304:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Process ForkPoolWorker-279:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-302:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "<ipython-input-3-ee4f88abbe3c>", line 60, in expe
#     return numpy.exp(-left)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-297:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "<ipython-input-3-ee4f88abbe3c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 343, in get
#     res = self._reader.recv_bytes()
#   File "<ipython-input-3-ee4f88abbe3c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "<ipython-input-3-ee4f88abbe3c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "<ipython-input-3-ee4f88abbe3c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<ipython-input-3-ee4f88abbe3c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "<ipython-input-3-ee4f88abbe3c>", line 115, in evalSymbReg
#     return max(sqerrors),
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<string>", line 1, in <lambda>
# KeyboardInterrupt
#   File "<ipython-input-3-ee4f88abbe3c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<string>", line 1, in <lambda>
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "<ipython-input-3-ee4f88abbe3c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "<ipython-input-3-ee4f88abbe3c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# KeyboardInterrupt
#   File "<ipython-input-3-ee4f88abbe3c>", line 60, in expe
#     return numpy.exp(-left)
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "<ipython-input-3-ee4f88abbe3c>", line 60, in expe
#     return numpy.exp(-left)
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-3-ee4f88abbe3c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "<string>", line 1, in <lambda>
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "<ipython-input-3-ee4f88abbe3c>", line 115, in evalSymbReg
#     return max(sqerrors),
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<string>", line 1, in <lambda>
#   File "<ipython-input-3-ee4f88abbe3c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<string>", line 1, in <lambda>
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-308:
#   File "<ipython-input-3-ee4f88abbe3c>", line 60, in expe
#     return numpy.exp(-left)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "<ipython-input-3-ee4f88abbe3c>", line 115, in evalSymbReg
#     return max(sqerrors),
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "<ipython-input-3-ee4f88abbe3c>", line 112, in <genexpr>
#     sqerrors = ((func(x) - f[x])**2 for x in points)
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
